# %%
import yfinance as yf
import pandas as pd
import numpy as np
import scipy.stats as sc
import scipy.linalg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sentiment = pd.read_csv("sentiment4.csv")
sentiment
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
#      Death_Count_Day  Positive_Count_Day
# ...

# %%
def get_data(stock_name):
    stock = yf.Ticker(stock_name).history(start="2020-02-11", end="2020-10-31") # from 2020-02-11 to 2020-10-30
    dates = []
    for x in range(len(stock)):
        newdate = str(stock.index[x])
        newdate = newdate[0:10]
        dates.append(newdate)
    stock['Date'] = dates
    
    split = []
    i = 0
    for date in sentiment.Date:
        if date in stock.Date:
            split.append(stock.iat[i,6])  # Stock Splits
            i+=1
        else:
            split.append(0)
    
    price = np.zeros(263)
    i = 0
    for date in sentiment.Date:
        if date in stock.Date:
            d = "20" + date[6:] + "-" + date[0:2] + "-" + date[3:5]  
            price[i] = stock[stock.Date == d].Close[0]
        else:
            price[i] = 0
        i+=1
    
    for i in range(1, len(price)):
        if price[i] == 0 :
            if i != len(price)-1:
                next_price = 0
                for j in range(i+1,i+7):
                    if price[j] != 0:
                        next_price = price[j]
                        break
                price[i] = 0.5 * (price[i-1] + next_price)
            else:
                price[i] = price[i-1]
    
    sentiment["Price"] = price
    sentiment["Stock Splits"] = split
    return sentiment

# %%
Walmart = get_data('WMT')
pd.DataFrame(Walmart).to_csv(r'C:\Users\suziy\OneDrive\Desktop\WMT_adjclose.csv', index=False)
Walmart
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
Target = get_data('TGT')
pd.DataFrame(Target).to_csv(r'C:\Users\suziy\OneDrive\Desktop\TGT_adjclose.csv', index=False)
Target
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
Macy = get_data('M')
pd.DataFrame(Macy).to_csv(r'C:\Users\suziy\OneDrive\Desktop\M_adjclose.csv', index=False)
Macy
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
Lululemon = get_data('LULU')
pd.DataFrame(Lululemon).to_csv(r'C:\Users\suziy\OneDrive\Desktop\LULU_adjclose.csv', index=False)
Lululemon
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
Costco = get_data('COST')
pd.DataFrame(Costco).to_csv(r'C:\Users\suziy\OneDrive\Desktop\COST_adjclose.csv', index=False)
Costco
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
Nordstrom = get_data('JWN')
pd.DataFrame(Nordstrom).to_csv(r'C:\Users\suziy\OneDrive\Desktop\JWN_adjclose.csv', index=False)
Nordstrom
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
HomeDepot = get_data('HD')
pd.DataFrame(HomeDepot).to_csv(r'C:\Users\suziy\OneDrive\Desktop\HD_adjclose.csv', index=False)
HomeDepot
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
Kohl = get_data('KSS')
pd.DataFrame(Kohl).to_csv(r'C:\Users\suziy\OneDrive\Desktop\KSS_adjclose.csv', index=False)
Kohl
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
JCPenney = get_data('JCPNQ')
pd.DataFrame(JCPenney).to_csv(r'C:\Users\suziy\OneDrive\Desktop\JCPNQ_adjclose.csv', index=False)
JCPenney
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...

# %%
Ulta = get_data('ULTA')
pd.DataFrame(Ulta).to_csv(r'C:\Users\suziy\OneDrive\Desktop\ULTA_adjclose.csv', index=False)
Ulta
# Out:
#      Total_Sentiment  Avg_Sentiment  Vaccine  Death  Shut  Spread      Date  \
# 0             1.1162       0.085862        0      0     0       0  02/11/20
# 1            -1.3723      -0.098021        2      3     1       1  02/12/20
# 2            -1.3975      -0.093167        0      3     0       0  02/13/20
# 3             0.0919       0.009190        0      1     2       1  02/14/20
# 4             0.0000       0.000000        1      0     0       0  02/15/20
# ..               ...            ...      ...    ...   ...     ...       ...
# 258          -2.3450      -0.045096        6      4     3       1  10/26/20
# 259          -6.0231      -0.109511        5      8     2       3  10/27/20
# 260          -2.0074      -0.030883        4      4     8       3  10/28/20
# 261          -2.5717      -0.052484        3      1     6       3  10/29/20
# 262           1.2955       0.143944        1      0     0       1  10/30/20
#
# ...
